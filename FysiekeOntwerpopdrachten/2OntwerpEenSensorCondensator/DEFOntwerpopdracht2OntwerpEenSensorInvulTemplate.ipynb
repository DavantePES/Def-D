# %% [markdown]
# # DEF-D Fysieke Ontwerpopdracht 2 invul template

# %% [markdown]
# ## Groep informatie
#
# Aan het einde van deze ontwerpopdracht lever je als groep één gezamenlijk notebook in (als in *PR* op GitHub en de link op Brightspace). Zet jullie groepsnummer, studienummers en namen in onderstaande tabel zodat wij zeker weten dat het groepsvormen goed is gegaan.
#
# | Groep: XX     |  |
# | :-------------|:-------------|
# | Davante Scheers |  6580599 |
# | Bob Villerius | 6483895 |
# | Daan d' Engelbronner| 6537812 |
# | Planning Groep: 42     | 10:45 / 17:30  |
# |---|---|
# | Sanity Check | 10:45 - 11:45 |
# | Condensator Bouwen | 11:45 - 12:15 |
# | Condensator Testen/Meten | 12:15 - 12:30 |
# | Pauze 1 | 12:30 - 13:45 |
# | Synthese | 13:45 - 14:15 |
# | Sensor Ontwerpen | 14:15 - 14:30 |
# | Sensor Bouwen | 14:30 - 15:30 |
# | Pauze 2 | 15:30 - 15:45 |
# | Sensor Data Verwerken | 15:45 - 16:30 |
# | Controleren / Afvinken / Opruimen | 16:30 - 17:30 |

# %% [markdown]
# ## *Opdracht 1*: Sanity check 3

# %% [markdown]
# #### Voeg hier een foto van de schets van je plaatcondensator in. Geef daarbij ook duidelijk de waarde van $A$ en $d$ aan.
# <img src="FotoSchetsCondensator.jpeg" alt="schets student 1" width="400"/>

# %% [markdown]
# A is hier 0.01 m^2
#
# d is hier ongveer 1 millimeter = 0.001 m

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit

epsilon0 = 8.854e-12  # permittiviteit van vacuum (F/m)

# Schrijf hier een python functie die de capaciteit van een plaatcondensator uitrekent. Zorg dat de functie
# als input de ontwerpparameters van de vlakke plaat formule accepteert (oppervlakte, afstand en diëlektrische
# constante) en als output de capaciteit van de vlakke plaat condensator met die ontwerpparameters.
# Je gaat deze formule de rest van de dag gebruiken: controleer hem goed!

def vlakkeplaat(A,d, epsilon):
    C = epsilon * A/d
    return C

# Optioneel: schrijf je functie zodanig dat je arrays als input kan geven en (dus) ook arrays als output.

# %%
# Gebruik je formule om uit te rekenen wat je verwacht dat de capaciteit van jullie vlakke plaat condensatoren
# gaat zijn.

epsilon_polypropyleen = 2.2 * epsilon0
d = 0.0006
A = 0.1**2
C_berekend = vlakkeplaat(A, d, epsilon_polypropyleen)
print(C_berekend / 10**-12, "pF. Dit is de  berekende capaciteit van onze plaatcondensator.")

# C = [functieNaam(2.0), functieNaam(4.7),functieNaam(1.2)]


# print(f"Berekende capaciteit plaatcondensator groep XX is {C[0]:.1f} pF")
C_gemeten = 1.7/(1000*8*2*np.pi*100000)
print(C_gemeten / 10**-12, "pF. Dit is de gemeten capaciteit van onze plaatcondensator.")
# Out:
# 324.6466666666667 pF. Dit is de  berekende capaciteit van onze plaatcondensator.
# 338.20425407027767 pF. Dit is de gemeten capaciteit van onze plaatcondensator.

# %% [markdown]
# #### Voeg hier een foto van je plaatcondensator en van de meting op de scope in. Dus 2 foto's.
# ![scope meting 1](FotoCondensatorOpstelling.jpeg)
# ![scope meting 2](FotoCondensatorMeting.jpeg)

# %% [markdown]
# ### Meting capaciteit
# Vul onderstaande tabel in. Bij Sanity check 2 heb je afgeleid hoe je van berekende capaciteit naar berekend voltage gaat en terug.
#
#
# | Namen         | Berekende capaciteit   | Berekend Voltage | Gemeten Voltage | Gemeten capaciteit   |
# |-------------|-------------:|-------------:|-------------:|-------------:|
# | groep 42| 200pF | 1.34 V | 1.7V | 338 pF |
#
# Het gemeten voltage/capaciteit is hoger dan onze berekende waarde, dit komt waarschijnlijk doordat we voor d een schatting hebben gemaakt die waarschijnlijk boven de daadwerkelijke waarde van d zit, waardoor de meting hoger uitkomt dan onze berekening.

# %% [markdown]
# ## *Opdracht 2:* Synthese.

# %% [markdown]
# #### Voeg hier voor een foto van je schets(en) van minimaal drie sensoren in.
# ![drie schetsen](SensorSchets1Massa.jpeg)
# ![drie schetsen](SensorSchets2Luchtdruk.jpeg)
# ![drie schetsen](SensorSchets3Zoutconcentratie.jpeg)

# %% [markdown]
# ## Opdracht 3: Welke sensor gaan jullie maken?

# %% [markdown]
# Wij gaan een sensor maken die massa meet. (Schets 1)

# %% [markdown]
# ## Opdracht 4: Uitgewerkte schets (afmetingen!) en plot van de ontwerpgrafiek.

# %% [markdown]
# #### Voeg hier een foto van jullie uitgewerkte  schets van de sensor die jullie gaan maken in
# ![uitgewerkte schets](GedetaileerdeSchets.jpeg)

# %%
capaciteiten = [12, 338]
massas = [2.5, 0]

# Het elastiek rekt recht evenredig uit met de kracht op het elastiek. De zwaartekracht is recht evenredig met de massa.
# Het effectieve oppervlakte van de condensator daalt recht evenredig met de uitrekking van het elastiek en daarmee met de grootte van de massa.
# De capaciteit van de condensator is recht evenredig met het effectieve oppervlakte van de condensator.
# Dus de capaciteit van de condensator is recht evenredig met de massa die aan het elastiek hangt. 

# De verwachtte verandering van de capaciteit is van 338 pF naar 12 pF, 
# aangezien een massa van 0g overeenkomt met 0 uitrekking van het elastiek en daarmee met het maximale effectieve oppervlakte van de condensator,
# wat overeenkomt met de gemeten waarde van 338 pF.


# Metingen voor berekenen veerconstante
C_meting2 = np.array([128.2, 111.5, 105.5, 91.9, 88.8, 69.0, 62.6, 53.1]) # in pF
M_meting2 = np.array([0, 0.111, 0.2744, 0.434, 0.482, 0.6425, 0.8325, 0.9725]) # in kg

# Lineaire fit
def lineaire_fit(M, a, b):
    return a * M + b

# Uitvoeren van de fit
popt2, pcov2 = curve_fit(lineaire_fit, M_meting2, C_meting2)
a_fit2, b_fit2 = popt2

# Berekenen van de veerconstante k

g = 9.81 # m/s^2
epsilon_lucht = epsilon0

C_F = C_meting2 * 1e-12 # Capaciteit in Farad
d0 = epsilon0 * 0.01 / C_F[0] # aftsand tussen de platen berekenen
w = 0.1       # m (breedte plaat)

A = C_F * d0 / epsilon_lucht   # oppervlakte in m^2

u = (0.01 - A) / w   # uitrekking in m

# uitrekking per massa

for i in range(len(M_meting2)):
    if M_meting2[i] == 0:
        continue  # overslaan van de eerste meting (0 massa)
    else:
        print(f"Uitrekking u bij massa {M_meting2[i]:.3f} kg: {u[i]:.6f} m")

F = M_meting2 * g # kracht in Newton
# Formule veerconstante
k_perpunt = F / u # de veerconstante per punt

# Resultaat printen)
k_mean = np.mean(k_perpunt[1:])   # gemiddelde, eerste punt (0 massa) overslaan
for i, k in enumerate(k_perpunt):
    print(f"Veerconstante k bij massa {M_meting2[i]:.3f} kg: {k:.1f} N/m")
print(f"Gemiddelde veerconstante k ≈ {k_mean:.1f} N/m")

massas = np.linspace(0, 1.5, 200)

u_theorie = (massas * g) / k_mean  # m
C_theorie = epsilon_lucht * w * (0.1 - u_theorie) / d0  # F


plt.plot(massas, C_theorie*1e12, 'r')
plt.ylabel('$C$ (pF)')
plt.xlabel('$M$ (kg)')
plt.title('Ontwerpgrafiek')
plt.xlim(0, 1.5)
plt.show()
# Out:
# Uitrekking u bij massa 0.111 kg: 0.013027 m
# Uitrekking u bij massa 0.274 kg: 0.017707 m
# Uitrekking u bij massa 0.434 kg: 0.028315 m
# Uitrekking u bij massa 0.482 kg: 0.030733 m
# Uitrekking u bij massa 0.642 kg: 0.046178 m
# Uitrekking u bij massa 0.833 kg: 0.051170 m
# Uitrekking u bij massa 0.973 kg: 0.058580 m
# Veerconstante k bij massa 0.000 kg: -0.0 N/m
# Veerconstante k bij massa 0.111 kg: 83.6 N/m
# Veerconstante k bij massa 0.274 kg: 152.0 N/m
# Veerconstante k bij massa 0.434 kg: 150.4 N/m
# Veerconstante k bij massa 0.482 kg: 153.9 N/m
# Veerconstante k bij massa 0.642 kg: 136.5 N/m
# Veerconstante k bij massa 0.833 kg: 159.6 N/m
# Veerconstante k bij massa 0.973 kg: 162.9 N/m
# Gemiddelde veerconstante k ≈ 142.7 N/m

# %% [markdown]
# ## Opdracht 5: Invullen tabel LTSpice.

# %% [markdown]
# ![uitgewerkte schets](PlotLTSpice.png)

# %% [markdown]
# |         | Capaciteit waarde (pF)  | LTSpice berekend output Vpp (mV)|
# |-------------|-------------:|-------------:|
# | minimale capaciteit| 12 | 120.4 |
# | gemiddelde capaciteit| 175 | 1748 |
# | maximale capaciteit| 338 | 3300 |

# %% [markdown]
# ## Opdracht 6: Foto's werkende opstelling.

# %% [markdown]
# #### Voeg hier de foto's van je sensoren in actie in.
# ![opstelling 1](FotoOpstelling1.jpeg)
# ![meting 1](FotoMeting2.jpeg)
# ![opstelling 2](FotoOpstelling2.jpeg)
# ![meting 2](FotoMeting1.jpeg)

# %% [markdown]
# ## Opdracht 7: Plot de kalibratiegrafiek.

# %%
# Plot hier je gemeten kalibratiegrafiek en plot in dezelfde figuur ook je verwachte ontwerpgrafiek.
C_meting = np.array([253.4, 225.1, 212.3, 199.7, 189.0, 157.1, 117.3, 95.1]) # in pF
M_meting = np.array([0, 0.111, 0.2744, 0.436, 0.4899, 0.642, 0.7693, 0.9725]) # in kg

# De reden dat dit een lineaire fit is is uitgelegd in opdracht 4.
def lineaire_fit(M, a, b):
    return a * M + b

popt, pcov = curve_fit(lineaire_fit, M_meting, C_meting)
a_fit, b_fit = popt

x_fit = np.linspace(0, 1, 100)
y_fit = lineaire_fit(x_fit, a_fit, b_fit)

plt.plot(x_fit, y_fit, label='lineaire fit')
plt.errorbar(M_meting, C_meting, yerr=10, xerr=0.002, fmt='ro', ecolor='red', alpha=0.5, label='Data')
plt.legend()
plt.title('Sensor kalibratiegrafiek')
plt.xlabel('$M$ (kg)')
plt.ylabel('$C$ (pF)')
plt.xlim(0, 1)
plt.ylim(0, 300)

uncertainty = np.sqrt(np.diag(pcov))/np.abs(a_fit)
print(f"De onzekerheden in a en b zijn respectievelijk {uncertainty[0]} en {uncertainty[1]}")
# Out:
# De onzekerheden in a en b zijn respectievelijk 0.08033924562649757 en 0.04461773934794388

# %% [markdown]
# ## Opdracht 8: Vul de tekst aan.

# %% [markdown]
# Onze sensor kan nog verbetered worden door de volgende verbeteringen (minimaal 2):
#
# * Op de plek waar de bovenste plaat opzij schuift door de massa gaat dat best stroef. Hier kan een katrol toegevoegd worden zodat hij makkelijker schuift en dus een accurater capaciteit tegen gewicht geeft.
# * De bovenste plaat schuift ook een beetje links/rechts boven de onderste, hierdoor verandert het oppervlak (en dus de capaciteit) ook.
# Een oplossing is een soort muurtje links en rechts van de plaat te maken zodat de plaat minder opzij schuift.
#
# We hebben uitgekozen om de tweede verbetering uit te voeren.

# %% [markdown]
# ## Opdracht 9: Uiteindelijke ontwerp en kalibratiegrafiek.

# %% [markdown]
# #### Voeg hier een foto van je uiteindelijke sensor in.
# ![foto sensor](Verbeterdeopstelling.jpg)

# %%
# Plot hier je oorspronkelijke en je uiteindelijke kalibratiegrafieken, fit daar een bijpassende lijn door
# en zet ook de verwachte ontwerpgrafiek erbij
# Plot hier je gemeten kalibratiegrafiek en plot in dezelfde figuur ook je verwachte ontwerpgrafiek.
C_meting2 = np.array([128.2, 111.5, 105.5, 91.9, 88.8, 69.0, 62.6, 53.1]) # in pF
M_meting2 = np.array([0, 0.111, 0.2744, 0.434, 0.482, 0.6425, 0.8325, 0.9725]) # in kg

# De reden dat dit een lineaire fit is is uitgelegd in opdracht 4.
def lineaire_fit(M, a, b):
    return a * M + b

popt2, pcov2 = curve_fit(lineaire_fit, M_meting2, C_meting2)
a_fit2, b_fit2 = popt2

x_fit2 = np.linspace(0, 1, 100)
y_fit2 = lineaire_fit(x_fit2, a_fit2, b_fit2)

plt.plot(x_fit2, y_fit2, label='lineaire fit')
plt.errorbar(M_meting2, C_meting2, yerr=7, xerr=0.002, fmt='bo', ecolor='blue', label="Data")
plt.plot(massas, C_theorie*1e12, 'r', label='theorie')
plt.legend()
plt.title('Verbeterde Sensor kalibratiegrafiek')
plt.xlabel('$M$ (kg)')
plt.ylabel('$C$ (pF)')
plt.xlim(0, 1)
plt.ylim(0, 150)

uncertainty2 = np.sqrt(np.diag(pcov2))/np.abs(a_fit2)
print(f"De onzekerheden in a en b zijn respectievelijk {uncertainty2[0]} en {uncertainty2[1]}")
# Out:
# De onzekerheden in a en b zijn respectievelijk 0.05749584284600233 en 0.03252402100305129

# %% [markdown]
# ## Opdracht 10: Vul hieronder de conclusie in.

# %% [markdown]
# De sensor is geschikt om massa te meten, want er zijn acht metingen uitgevoerd met massas tussen 0 en 1 kilogram, wat overeenkwam met waarden tussen de 50 en 125pF.
# Voordat de verbetering in de opstelling was uitgevoerd, was de onzekerheid in de metingen 8.0%. Na de verbetering was de onzekerheid in de metingen 5.7%. De verbetering heeft dus geholpen met het verlagen van de onzekerheid met ~30%.
# De verbetering was stokjes toevoegen aan de linker en rechterkant van de bovenste plaat waardoor deze niet heen en weer schuift, waardoor er minder variatie zit in het effectieve oppervlakte.
# Het verschil tussen de ontwerpgrafiek en de uitendelijke kalibratiegrafiek is dat de hoeveelheid pF bij 0 kg bij de uiteindelijke kalibratiegrafiek veel lager lag.
# De uiteindelijke kalibratiegrafiek komt bijna perfect overeen met de ontwerpgrafiek.

# %% [markdown]
# ## Opdracht 11: Kopieer hieronder de leerdoelen.
# 1. Het kunnen gebruiken van de eigenschappen van een elektrische component in een ontwerpproces om een fysische grootheid te meten.
# 2. Kennis hebben van gedrag van elektrische componenten en meetopstellingen.
# 3. Onderdelen van een datasheet zoals een kalibratiegrafiek opstellen, gevoeligheid en onzekerheid beschrijven.

# %% [markdown]
# !!!De volgorde hier is anders dan in de opdracht. Wij hebben hier de volgorde van opdracht 11 aangenomen.!!!

# %% [markdown]
# ## kopieer hier de cel(len) waaruit blijkt dat jullie leerdoel 1 beheersen.

# %% [markdown]
# ## *Opdracht 1*: Sanity check 3

# %% [markdown]
# #### Voeg hier een foto van de schets van je plaatcondensator in. Geef daarbij ook duidelijk de waarde van $A$ en $d$ aan.
# <img src="FotoSchetsCondensator.jpeg" alt="schets student 1" width="400"/>

# %% [markdown]
# A is hier 0.01 m^2
#
# d is hier ongveer 1 millimeter = 0.001 m

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit

epsilon0 = 8.854e-12  # permittiviteit van vacuum (F/m)

# Schrijf hier een python functie die de capaciteit van een plaatcondensator uitrekent. Zorg dat de functie
# als input de ontwerpparameters van de vlakke plaat formule accepteert (oppervlakte, afstand en diëlektrische
# constante) en als output de capaciteit van de vlakke plaat condensator met die ontwerpparameters.
# Je gaat deze formule de rest van de dag gebruiken: controleer hem goed!

def vlakkeplaat(A,d, epsilon):
    C = epsilon * A/d
    return C

# Optioneel: schrijf je functie zodanig dat je arrays als input kan geven en (dus) ook arrays als output.

# %%
# Gebruik je formule om uit te rekenen wat je verwacht dat de capaciteit van jullie vlakke plaat condensatoren
# gaat zijn.

epsilon_polypropyleen = 2.2 * epsilon0
d = 0.0006
A = 0.1**2
C_berekend = vlakkeplaat(A, d, epsilon_polypropyleen)
print(C_berekend / 10**-12, "pF. Dit is de  berekende capaciteit van onze plaatcondensator.")

# C = [functieNaam(2.0), functieNaam(4.7),functieNaam(1.2)]


# print(f"Berekende capaciteit plaatcondensator groep XX is {C[0]:.1f} pF")
C_gemeten = 1.7/(1000*8*2*np.pi*100000)
print(C_gemeten / 10**-12, "pF. Dit is de gemeten capaciteit van onze plaatcondensator.")
# Out:
# 324.6466666666667 pF. Dit is de  berekende capaciteit van onze plaatcondensator.
# 338.20425407027767 pF. Dit is de gemeten capaciteit van onze plaatcondensator.

# %% [markdown]
# #### Voeg hier een foto van je plaatcondensator en van de meting op de scope in. Dus 2 foto's.
# ![scope meting 1](FotoCondensatorOpstelling.jpeg)
# ![scope meting 2](FotoCondensatorMeting.jpeg)

# %% [markdown]
# ### Meting capaciteit
# Vul onderstaande tabel in. Bij Sanity check 2 heb je afgeleid hoe je van berekende capaciteit naar berekend voltage gaat en terug.
#
#
# | Namen         | Berekende capaciteit   | Berekend Voltage | Gemeten Voltage | Gemeten capaciteit   |
# |-------------|-------------:|-------------:|-------------:|-------------:|
# | groep 42| 200pF | 1.34 V | 1.7V | 338 pF |
#
# Het gemeten voltage/capaciteit is hoger dan onze berekende waarde, dit komt waarschijnlijk doordat we voor d een schatting hebben gemaakt die waarschijnlijk boven de daadwerkelijke waarde van d zit, waardoor de meting hoger uitkomt dan onze berekening.

# %% [markdown]
# ## *Opdracht 2:* Synthese.

# %% [markdown]
# #### Voeg hier voor een foto van je schets(en) van minimaal drie sensoren in.
# ![drie schetsen](SensorSchets1Massa.jpeg)
# ![drie schetsen](SensorSchets2Luchtdruk.jpeg)
# ![drie schetsen](SensorSchets3Zoutconcentratie.jpeg)

# %% [markdown]
# ## Opdracht 4: Uitgewerkte schets (afmetingen!) en plot van de ontwerpgrafiek.

# %% [markdown]
# #### Voeg hier een foto van jullie uitgewerkte  schets van de sensor die jullie gaan maken in
# ![uitgewerkte schets](GedetaileerdeSchets.jpeg)

# %%
capaciteiten = [12, 338]
massas = [2.5, 0]

# Het elastiek rekt recht evenredig uit met de kracht op het elastiek. De zwaartekracht is recht evenredig met de massa.
# Het effectieve oppervlakte van de condensator daalt recht evenredig met de uitrekking van het elastiek en daarmee met de grootte van de massa.
# De capaciteit van de condensator is recht evenredig met het effectieve oppervlakte van de condensator.
# Dus de capaciteit van de condensator is recht evenredig met de massa die aan het elastiek hangt. 

# De verwachtte verandering van de capaciteit is van 338 pF naar 12 pF, 
# aangezien een massa van 0g overeenkomt met 0 uitrekking van het elastiek en daarmee met het maximale effectieve oppervlakte van de condensator,
# wat overeenkomt met de gemeten waarde van 338 pF.


# Metingen voor berekenen veerconstante
C_meting2 = np.array([128.2, 111.5, 105.5, 91.9, 88.8, 69.0, 62.6, 53.1]) # in pF
M_meting2 = np.array([0, 0.111, 0.2744, 0.434, 0.482, 0.6425, 0.8325, 0.9725]) # in kg

# Lineaire fit
def lineaire_fit(M, a, b):
    return a * M + b

# Uitvoeren van de fit
popt2, pcov2 = curve_fit(lineaire_fit, M_meting2, C_meting2)
a_fit2, b_fit2 = popt2

# Berekenen van de veerconstante k

g = 9.81 # m/s^2
epsilon_lucht = epsilon0

C_F = C_meting2 * 1e-12 # Capaciteit in Farad
d0 = epsilon0 * 0.01 / C_F[0] # aftsand tussen de platen berekenen
w = 0.1       # m (breedte plaat)

A = C_F * d0 / epsilon_lucht   # oppervlakte in m^2

u = (0.01 - A) / w   # uitrekking in m

# uitrekking per massa

for i in range(len(M_meting2)):
    if M_meting2[i] == 0:
        continue  # overslaan van de eerste meting (0 massa)
    else:
        print(f"Uitrekking u bij massa {M_meting2[i]:.3f} kg: {u[i]:.6f} m")

F = M_meting2 * g # kracht in Newton
# Formule veerconstante
k_perpunt = F / u # de veerconstante per punt

# Resultaat printen)
k_mean = np.mean(k_perpunt[1:])   # gemiddelde, eerste punt (0 massa) overslaan
for i, k in enumerate(k_perpunt):
    print(f"Veerconstante k bij massa {M_meting2[i]:.3f} kg: {k:.1f} N/m")
print(f"Gemiddelde veerconstante k ≈ {k_mean:.1f} N/m")

massas = np.linspace(0, 1.5, 200)

u_theorie = (massas * g) / k_mean  # m
C_theorie = epsilon_lucht * w * (0.1 - u_theorie) / d0  # F


plt.plot(massas, C_theorie*1e12, 'r')
plt.ylabel('$C$ (pF)')
plt.xlabel('$M$ (kg)')
plt.title('Ontwerpgrafiek')
plt.xlim(0, 1.5)
plt.show()
# Out:
# Uitrekking u bij massa 0.111 kg: 0.013027 m
# Uitrekking u bij massa 0.274 kg: 0.017707 m
# Uitrekking u bij massa 0.434 kg: 0.028315 m
# Uitrekking u bij massa 0.482 kg: 0.030733 m
# Uitrekking u bij massa 0.642 kg: 0.046178 m
# Uitrekking u bij massa 0.833 kg: 0.051170 m
# Uitrekking u bij massa 0.973 kg: 0.058580 m
# Veerconstante k bij massa 0.000 kg: -0.0 N/m
# Veerconstante k bij massa 0.111 kg: 83.6 N/m
# Veerconstante k bij massa 0.274 kg: 152.0 N/m
# Veerconstante k bij massa 0.434 kg: 150.4 N/m
# Veerconstante k bij massa 0.482 kg: 153.9 N/m
# Veerconstante k bij massa 0.642 kg: 136.5 N/m
# Veerconstante k bij massa 0.833 kg: 159.6 N/m
# Veerconstante k bij massa 0.973 kg: 162.9 N/m
# Gemiddelde veerconstante k ≈ 142.7 N/m

# %% [markdown]
# ## Opdracht 6: Foto's werkende opstelling.

# %% [markdown]
# #### Voeg hier de foto's van je sensoren in actie in.
# ![opstelling 1](FotoOpstelling1.jpeg)
# ![meting 1](FotoMeting2.jpeg)
# ![opstelling 2](FotoOpstelling2.jpeg)
# ![meting 2](FotoMeting1.jpeg)

# %% [markdown]
# ## Opdracht 9: Uiteindelijke ontwerp en kalibratiegrafiek.

# %% [markdown]
# #### Voeg hier een foto van je uiteindelijke sensor in.
# ![foto sensor](Verbeterdeopstelling.jpg)

# %% [markdown]
# ## kopieer hier de cel(len) waaruit blijkt dat jullie leerdoel 2 beheersen.

# %% [markdown]
# ## *Opdracht 1*: Sanity check 3

# %% [markdown]
# #### Voeg hier een foto van de schets van je plaatcondensator in. Geef daarbij ook duidelijk de waarde van $A$ en $d$ aan.
# <img src="FotoSchetsCondensator.jpeg" alt="schets student 1" width="400"/>

# %% [markdown]
# A is hier 0.01 m^2
#
# d is hier ongveer 1 millimeter = 0.001 m

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit

epsilon0 = 8.854e-12  # permittiviteit van vacuum (F/m)

# Schrijf hier een python functie die de capaciteit van een plaatcondensator uitrekent. Zorg dat de functie
# als input de ontwerpparameters van de vlakke plaat formule accepteert (oppervlakte, afstand en diëlektrische
# constante) en als output de capaciteit van de vlakke plaat condensator met die ontwerpparameters.
# Je gaat deze formule de rest van de dag gebruiken: controleer hem goed!

def vlakkeplaat(A,d, epsilon):
    C = epsilon * A/d
    return C

# Optioneel: schrijf je functie zodanig dat je arrays als input kan geven en (dus) ook arrays als output.

# %%
# Gebruik je formule om uit te rekenen wat je verwacht dat de capaciteit van jullie vlakke plaat condensatoren
# gaat zijn.

epsilon_polypropyleen = 2.2 * epsilon0
d = 0.0006
A = 0.1**2
C_berekend = vlakkeplaat(A, d, epsilon_polypropyleen)
print(C_berekend / 10**-12, "pF. Dit is de  berekende capaciteit van onze plaatcondensator.")

# C = [functieNaam(2.0), functieNaam(4.7),functieNaam(1.2)]


# print(f"Berekende capaciteit plaatcondensator groep XX is {C[0]:.1f} pF")
C_gemeten = 1.7/(1000*8*2*np.pi*100000)
print(C_gemeten / 10**-12, "pF. Dit is de gemeten capaciteit van onze plaatcondensator.")
# Out:
# 324.6466666666667 pF. Dit is de  berekende capaciteit van onze plaatcondensator.
# 338.20425407027767 pF. Dit is de gemeten capaciteit van onze plaatcondensator.

# %% [markdown]
# #### Voeg hier een foto van je plaatcondensator en van de meting op de scope in. Dus 2 foto's.
# ![scope meting 1](FotoCondensatorOpstelling.jpeg)
# ![scope meting 2](FotoCondensatorMeting.jpeg)

# %% [markdown]
# ### Meting capaciteit
# Vul onderstaande tabel in. Bij Sanity check 2 heb je afgeleid hoe je van berekende capaciteit naar berekend voltage gaat en terug.
#
#
# | Namen         | Berekende capaciteit   | Berekend Voltage | Gemeten Voltage | Gemeten capaciteit   |
# |-------------|-------------:|-------------:|-------------:|-------------:|
# | groep 42| 200pF | 1.34 V | 1.7V | 338 pF |
#
# Het gemeten voltage/capaciteit is hoger dan onze berekende waarde, dit komt waarschijnlijk doordat we voor d een schatting hebben gemaakt die waarschijnlijk boven de daadwerkelijke waarde van d zit, waardoor de meting hoger uitkomt dan onze berekening.

# %% [markdown]
# ## Opdracht 4: Uitgewerkte schets (afmetingen!) en plot van de ontwerpgrafiek.

# %% [markdown]
# #### Voeg hier een foto van jullie uitgewerkte  schets van de sensor die jullie gaan maken in
# ![uitgewerkte schets](GedetaileerdeSchets.jpeg)

# %%
capaciteiten = [12, 338]
massas = [2.5, 0]

# Het elastiek rekt recht evenredig uit met de kracht op het elastiek. De zwaartekracht is recht evenredig met de massa.
# Het effectieve oppervlakte van de condensator daalt recht evenredig met de uitrekking van het elastiek en daarmee met de grootte van de massa.
# De capaciteit van de condensator is recht evenredig met het effectieve oppervlakte van de condensator.
# Dus de capaciteit van de condensator is recht evenredig met de massa die aan het elastiek hangt. 

# De verwachtte verandering van de capaciteit is van 338 pF naar 12 pF, 
# aangezien een massa van 0g overeenkomt met 0 uitrekking van het elastiek en daarmee met het maximale effectieve oppervlakte van de condensator,
# wat overeenkomt met de gemeten waarde van 338 pF.


# Metingen voor berekenen veerconstante
C_meting2 = np.array([128.2, 111.5, 105.5, 91.9, 88.8, 69.0, 62.6, 53.1]) # in pF
M_meting2 = np.array([0, 0.111, 0.2744, 0.434, 0.482, 0.6425, 0.8325, 0.9725]) # in kg

# Lineaire fit
def lineaire_fit(M, a, b):
    return a * M + b

# Uitvoeren van de fit
popt2, pcov2 = curve_fit(lineaire_fit, M_meting2, C_meting2)
a_fit2, b_fit2 = popt2

# Berekenen van de veerconstante k

g = 9.81 # m/s^2
epsilon_lucht = epsilon0

C_F = C_meting2 * 1e-12 # Capaciteit in Farad
d0 = epsilon0 * 0.01 / C_F[0] # aftsand tussen de platen berekenen
w = 0.1       # m (breedte plaat)

A = C_F * d0 / epsilon_lucht   # oppervlakte in m^2

u = (0.01 - A) / w   # uitrekking in m

# uitrekking per massa

for i in range(len(M_meting2)):
    if M_meting2[i] == 0:
        continue  # overslaan van de eerste meting (0 massa)
    else:
        print(f"Uitrekking u bij massa {M_meting2[i]:.3f} kg: {u[i]:.6f} m")

F = M_meting2 * g # kracht in Newton
# Formule veerconstante
k_perpunt = F / u # de veerconstante per punt

# Resultaat printen)
k_mean = np.mean(k_perpunt[1:])   # gemiddelde, eerste punt (0 massa) overslaan
for i, k in enumerate(k_perpunt):
    print(f"Veerconstante k bij massa {M_meting2[i]:.3f} kg: {k:.1f} N/m")
print(f"Gemiddelde veerconstante k ≈ {k_mean:.1f} N/m")

massas = np.linspace(0, 1.5, 200)

u_theorie = (massas * g) / k_mean  # m
C_theorie = epsilon_lucht * w * (0.1 - u_theorie) / d0  # F


plt.plot(massas, C_theorie*1e12, 'r')
plt.ylabel('$C$ (pF)')
plt.xlabel('$M$ (kg)')
plt.title('Ontwerpgrafiek')
plt.xlim(0, 1.5)
plt.show()
# Out:
# Uitrekking u bij massa 0.111 kg: 0.013027 m
# Uitrekking u bij massa 0.274 kg: 0.017707 m
# Uitrekking u bij massa 0.434 kg: 0.028315 m
# Uitrekking u bij massa 0.482 kg: 0.030733 m
# Uitrekking u bij massa 0.642 kg: 0.046178 m
# Uitrekking u bij massa 0.833 kg: 0.051170 m
# Uitrekking u bij massa 0.973 kg: 0.058580 m
# Veerconstante k bij massa 0.000 kg: -0.0 N/m
# Veerconstante k bij massa 0.111 kg: 83.6 N/m
# Veerconstante k bij massa 0.274 kg: 152.0 N/m
# Veerconstante k bij massa 0.434 kg: 150.4 N/m
# Veerconstante k bij massa 0.482 kg: 153.9 N/m
# Veerconstante k bij massa 0.642 kg: 136.5 N/m
# Veerconstante k bij massa 0.833 kg: 159.6 N/m
# Veerconstante k bij massa 0.973 kg: 162.9 N/m
# Gemiddelde veerconstante k ≈ 142.7 N/m

# %% [markdown]
# ## Opdracht 5: Invullen tabel LTSpice.

# %% [markdown]
# ![uitgewerkte schets](PlotLTSpice.png)

# %% [markdown]
# |         | Capaciteit waarde (pF)  | LTSpice berekend output Vpp (mV)|
# |-------------|-------------:|-------------:|
# | minimale capaciteit| 12 | 120.4 |
# | gemiddelde capaciteit| 175 | 1748 |
# | maximale capaciteit| 338 | 3300 |

# %% [markdown]
# ## Opdracht 8: Vul de tekst aan.

# %% [markdown]
# Onze sensor kan nog verbetered worden door de volgende verbeteringen (minimaal 2):
#
# * Op de plek waar de bovenste plaat opzij schuift door de massa gaat dat best stroef. Hier kan een katrol toegevoegd worden zodat hij makkelijker schuift en dus een accurater capaciteit tegen gewicht geeft.
# * De bovenste plaat schuift ook een beetje links/rechts boven de onderste, hierdoor verandert het oppervlak (en dus de capaciteit) ook.
# Een oplossing is een soort muurtje links en rechts van de plaat te maken zodat de plaat minder opzij schuift.
#
# We hebben uitgekozen om de tweede verbetering uit te voeren.

# %% [markdown]
# ## kopieer hier de cel(len) waaruit blijkt dat jullie leerdoel 3 beheersen.

# %% [markdown]
# ## Opdracht 7: Plot de kalibratiegrafiek.

# %%
# Plot hier je gemeten kalibratiegrafiek en plot in dezelfde figuur ook je verwachte ontwerpgrafiek.
C_meting = np.array([253.4, 225.1, 212.3, 199.7, 189.0, 157.1, 117.3, 95.1]) # in pF
M_meting = np.array([0, 0.111, 0.2744, 0.436, 0.4899, 0.642, 0.7693, 0.9725]) # in kg

# Het elastiek rekt recht evenredig uit met de kracht op het elastiek volgens F=kx. 
# De zwaartekracht is recht evenredig met de massa (F=mg). Omdat de krachten bij het 'wegen' in evenwicht zijn geldt: x=mg/k. 
# De uitrekking is dus recht evenredig met de massa.
# Het effectieve oppervlak van de plaat van de condensator wordt bepaald door A=l*b waarbij l en b de lengte en breedte zijn van het stuk plaat dat boven de andere plaat ligt.
# Het oppervlak daalt dus recht evenredig als de lengte afneemt.
# In onze opstelling is de uitrekking x hetzelfde als de oorsprongkelijke lengte van de plaat min de lengte van het effectieve oppervlakte. 
# Als voor de oorsprongkelijke lengte l0 wordt genomen, geldt hier dus x=l0-l. Hieruit volgt dus: l0-l=mg/k en dus l=l0-mg/k.
# Volgens de plaatformule (C=epsilon*A/d) is de capaciteit evenredig met het effectieve oppervlakte van de plaat.
# Hieruit volgt dus dat A=(l0-mg/k)*b en dus dat C=epsilon*b(l0-mg/k)/d --> C=epsilon*b*l0/d - epsilon*b*mg/(k*d). 
# Dit is in de vorm C=rm+c met r en c constanten. Het verband tussen C en m is dus lineair.

# De reden dat dit een lineaire fit is is uitgelegd in opdracht 4.
def lineaire_fit(M, a, b):
    return a * M + b

popt, pcov = curve_fit(lineaire_fit, M_meting, C_meting)
a_fit, b_fit = popt

x_fit = np.linspace(0, 1, 100)
y_fit = lineaire_fit(x_fit, a_fit, b_fit)

plt.plot(x_fit, y_fit, label='lineaire fit')
plt.errorbar(M_meting, C_meting, yerr=10, xerr=0.002, fmt='ro', ecolor='red', alpha=0.5, label='Data')
plt.legend()
plt.title('Sensor kalibratiegrafiek')
plt.xlabel('$M$ (kg)')
plt.ylabel('$C$ (pF)')
plt.xlim(0, 1)
plt.ylim(0, 300)

uncertainty = np.sqrt(np.diag(pcov))/np.abs(a_fit)
print(f"De onzekerheden in a en b zijn respectievelijk {uncertainty[0]} en {uncertainty[1]}")
# Out:
# De onzekerheden in a en b zijn respectievelijk 0.08033924562649757 en 0.04461773934794388

# %% [markdown]
# ## Opdracht 9: Uiteindelijke ontwerp en kalibratiegrafiek.

# %% [markdown]
# #### Voeg hier een foto van je uiteindelijke sensor in.
# ![foto sensor](Verbeterdeopstelling.jpg)

# %%
# Plot hier je oorspronkelijke en je uiteindelijke kalibratiegrafieken, fit daar een bijpassende lijn door
# en zet ook de verwachte ontwerpgrafiek erbij
# Plot hier je gemeten kalibratiegrafiek en plot in dezelfde figuur ook je verwachte ontwerpgrafiek.
C_meting2 = np.array([128.2, 111.5, 105.5, 91.9, 88.8, 69.0, 62.6, 53.1]) # in pF
M_meting2 = np.array([0, 0.111, 0.2744, 0.434, 0.482, 0.6425, 0.8325, 0.9725]) # in kg

# Het elastiek rekt recht evenredig uit met de kracht op het elastiek volgens F=kx. 
# De zwaartekracht is recht evenredig met de massa (F=mg). Omdat de krachten bij het 'wegen' in evenwicht zijn geldt: x=mg/k. 
# De uitrekking is dus recht evenredig met de massa.
# Het effectieve oppervlak van de plaat van de condensator wordt bepaald door A=l*b waarbij l en b de lengte en breedte zijn van het stuk plaat dat boven de andere plaat ligt.
# Het oppervlak daalt dus recht evenredig als de lengte afneemt.
# In onze opstelling is de uitrekking x hetzelfde als de oorsprongkelijke lengte van de plaat min de lengte van het effectieve oppervlakte. 
# Als voor de oorsprongkelijke lengte l0 wordt genomen, geldt hier dus x=l0-l. Hieruit volgt dus: l0-l=mg/k en dus l=l0-mg/k.
# Volgens de plaatformule (C=epsilon*A/d) is de capaciteit evenredig met het effectieve oppervlakte van de plaat.
# Hieruit volgt dus dat A=(l0-mg/k)*b en dus dat C=epsilon*b(l0-mg/k)/d --> C=epsilon*b*l0/d - epsilon*b*mg/(k*d). 
# Dit is in de vorm C=rm+c met r en c constanten. Het verband tussen C en m is dus lineair.

# Lineaire functie.
def lineaire_fit(M, a, b):
    return a * M + b

popt2, pcov2 = curve_fit(lineaire_fit, M_meting2, C_meting2)
a_fit2, b_fit2 = popt2

x_fit2 = np.linspace(0, 1, 100)
y_fit2 = lineaire_fit(x_fit2, a_fit2, b_fit2)

plt.plot(x_fit2, y_fit2, label='lineaire fit')
plt.errorbar(M_meting2, C_meting2, yerr=7, xerr=0.002, fmt='bo', ecolor='blue', label="Data")
plt.plot(massas, C_theorie*1e12, 'r', label='theorie')
plt.legend()
plt.title('Verbeterde Sensor kalibratiegrafiek')
plt.xlabel('$M$ (kg)')
plt.ylabel('$C$ (pF)')
plt.xlim(0, 1)
plt.ylim(0, 150)

uncertainty2 = np.sqrt(np.diag(pcov2))/np.abs(a_fit2)
print(f"De onzekerheden in a en b zijn respectievelijk {uncertainty2[0]} en {uncertainty2[1]}")
# Out:
# De onzekerheden in a en b zijn respectievelijk 0.05749584284600233 en 0.03252402100305129

# %% [markdown]
# ## Opdracht 10: Vul hieronder de conclusie in.

# %% [markdown]
# De sensor is geschikt om massa te meten, want er zijn acht metingen uitgevoerd met massas tussen 0 en 1 kilogram, wat overeenkwam met waarden tussen de 50 en 125pF.
# Voordat de verbetering in de opstelling was uitgevoerd, was de onzekerheid in de metingen 8.0%. Na de verbetering was de onzekerheid in de metingen 5.7%. De verbetering heeft dus geholpen met het verlagen van de onzekerheid met ~30%.
# De verbetering was stokjes toevoegen aan de linker en rechterkant van de bovenste plaat waardoor deze niet heen en weer schuift, waardoor er minder variatie zit in het effectieve oppervlakte.
# Het verschil tussen de ontwerpgrafiek en de uitendelijke kalibratiegrafiek is dat de hoeveelheid pF bij 0 kg bij de uiteindelijke kalibratiegrafiek veel lager lag. Dit verschil kunnen we niet verklaren. De verandering in capaciteit t.o.v. massa was in de uiteindelijke kalibratiegrafiek kleiner dan verwacht. Dit komt omdat we in onze ontwerpgrafiek de massa geschat hadden. Volgens de metingen komt de vlakkeplaat formule komt goed overeen met onze specifieke sensor.
